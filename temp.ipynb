# %%
from diffusers.utils import make_image_grid

# %%
from PIL import Image
from glob import glob

fns = sorted(glob("assets/*_*.png"))

# %%
pil_list = [Image.open(cur) for cur in fns]

# %%
make_image_grid([pil_list[0],pil_list[3]], 1, 2, 512)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x512>

# %%
images = []
for ko, en in zip(fns_ko, fns_en):
    images.append(make_image_grid([Image.open(ko), Image.open(en)], 1, 2))

# %%
for idx, cur in enumerate(images):
    cur.save(f"./assets/webtoon_{idx}.png")
